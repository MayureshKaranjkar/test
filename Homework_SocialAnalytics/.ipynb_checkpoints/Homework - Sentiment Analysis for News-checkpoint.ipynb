# %%
# Dependencies
import tweepy
from pprint import pprint
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# Import and Initialize Sentiment Analyzer
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %%
# Twitter API Keys
from config import (consumer_key,
                    consumer_secret,
                    access_token,
                    access_token_secret)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c62d72d3f9d5> in <module>()
#       1 # Twitter API Keys
# ----> 2 from config import (consumer_key,
#       3                     consumer_secret,
#       4                     access_token,
#       5                     access_token_secret)
#
# ModuleNotFoundError: No module named 'config'

# %%
consumer_api_key = "xxxx"

consumer_secret_api_key = "xxxx"

access_token_key = "xxxx"

access_token_secret_key = "xxxx"

# %%
# Setup Tweepy API Authentication
auth = tweepy.OAuthHandler(consumer_api_key, consumer_secret_api_key)
auth.set_access_token(access_token_key, access_token_secret_key)
api = tweepy.API(auth, parser=tweepy.parsers.JSONParser())

# %%
# Target Search Term
twitter_handles = ["BBC", "CBS", "CNN", "FoxNews", "nytimes"]

# Create an empty list to store sentiments
news_sentiments = []

#Loop through each twitter handle
for twitter_handle in twitter_handles:
         
    # Keep track of tweet counts by recent tweet first
    counter = 1  

    # Loop through 5 pages (20 per page) = 100 tweets per handle
    for x in range(1, 6):

        news_tweets = api.user_timeline(twitter_handle, result_type="recent", page=x)

        # Loop through all tweets
        for tweet in news_tweets:   
            
            tweet_datetimes = []
            
            # Run Vader Analysis on each tweet
            vader_results = analyzer.polarity_scores(tweet["text"])
            compound = vader_results["compound"]
            pos = vader_results["pos"]
            neu = vader_results["neu"]
            neg = vader_results["neg"]
            tweet_datetimes.append(tweet["created_at"])
            
            #Convert raw time to a sortable time for chart
            for raw_time in tweet_datetimes:
                converted_time = datetime.strptime(raw_time, "%a %b %d %H:%M:%S %z %Y")

            #Add sentiments for each tweet into a dictionary
            #Append dictionary to list
            news_sentiments.append({"TwitterHandle": twitter_handle,
                               "Tweet": tweet["text"],
                               "Date": converted_time, 
                               "Compound": compound,
                               "Positive": pos,
                               "Negative": neu,
                               "Neutral": neg,
                               "TweetsAgo": counter})

            # accumulate tweet number count for charts
            counter += 1

# %%
# Convert sentiments to DataFrame
# Reorder and then sort by Twitter handle and then by Date in descending order
news_sentiments_df = pd.DataFrame.from_dict(news_sentiments)
news_sentiments_df = news_sentiments_df[["TwitterHandle", "Date", "TweetsAgo", "Compound", "Positive", "Negative", "Neutral", "Tweet"]]
news_sentiments_df.sort_values(["TwitterHandle", "Date"], ascending=[True, False])
# Out:
#     TwitterHandle                      Date  TweetsAgo  Compound  Positive  \
# 0             BBC 2018-10-12 18:12:03+00:00          1   -0.6124     0.000
# 1             BBC 2018-10-12 16:05:08+00:00          2    0.4389     0.182
# 2             BBC 2018-10-12 15:44:40+00:00          3    0.7579     0.228
# 3             BBC 2018-10-12 15:25:04+00:00          4    0.0000     0.000
# 4             BBC 2018-10-12 14:43:35+00:00          5   -0.7096     0.000
# 5             BBC 2018-10-12 14:08:35+00:00          6    0.6114     0.174
# 6             BBC 2018-10-12 13:56:43+00:00          7    0.7430     0.249
# 7             BBC 2018-10-12 13:04:05+00:00          8   -0.3818     0.000
# 8             BBC 2018-10-12 12:04:05+00:00          9    0.4588     0.188
# 9             BBC 2018-10-12 11:42:59+00:00         10    0.5994     0.262
# 10            BBC 2018-10-12 11:03:05+00:00         11    0.0000     0.000
# 11            BBC 2018-10-12 10:56:18+00:00         12    0.6360     0.181
# 12            BBC 2018-10-12 10:49:13+00:00         13    0.0000     0.000
# 13            BBC 2018-10-12 10:47:24+00:00         14    0.7351     0.206
# 486     1.000    0.000  At least 5 states have now reported that they ...
# 487     1.000    0.000  We asked each girl to tell us the name of the ...
# 488     1.000    0.000  Get our On Politics newsletter delivered to yo...
# 489     0.581    0.170  After years as a drag on Democrats, health car...
# 490     0.778    0.000  RT @katierogers: Honestly, there were so many,...
# 491     1.000    0.000  Cinzia Russo is finishing up her last year of ...
# 492     1.000    0.000  Evening Briefing: Here's what you need to know...
# 493     1.000    0.000  Anndrine Lund lives in Norway and plans to stu...
# 494     0.582    0.418  RT @alanblinder: A panorama of ruin. Frantic e...
# 495     1.000    0.000  Lior Danieli lives in Israel and will be draft...
# 496     0.841    0.000  The Banksy painting that self-destructed after...
# 497     0.720    0.280  RT @noamscheiber: The neediest Marriott worker...
# 498     0.909    0.000  Jung Eun Yang lives in South Korea and her dre...
# 499     0.725    0.198  Global warming. Violence against women. Right-...
#
# [500 rows x 8 columns]

# %%
# Save Sentiments dataframe as CSV to same folder
news_sentiments_df.to_csv("Distinguishing_Sentiments.csv", index=False, encoding='utf-8')

# %%
# Plot all sentiments by Twitter handle
fig, ax = plt.subplots()
news_sentiments_df[news_sentiments_df['TwitterHandle'] == 'BBC'].plot(x='TweetsAgo', 
                                                            y='Compound', 
                                                            ax=ax, 
                                                            grid=True,
                                                            marker="o",
                                                            linewidth=0,
                                                            figsize=(20,10),
                                                            label='BBC')
news_sentiments_df[news_sentiments_df['TwitterHandle'] == 'CBS'].plot(x='TweetsAgo', 
                                                            y='Compound', 
                                                            ax=ax, 
                                                            grid=True,
                                                            marker="*",
                                                            linewidth=0,
                                                            figsize=(20,10),
                                                            label='CBS')
news_sentiments_df[news_sentiments_df['TwitterHandle'] == 'CNN'].plot(x='TweetsAgo', 
                                                            y='Compound', 
                                                            ax=ax, 
                                                            grid=True,
                                                            marker="^",
                                                            linewidth=0,
                                                            figsize=(20,10),
                                                            label='CNN')
news_sentiments_df[news_sentiments_df['TwitterHandle'] == 'FoxNews'].plot(x='TweetsAgo', 
                                                                y='Compound', 
                                                                ax=ax, 
                                                                grid=True,
                                                                marker="s",
                                                                linewidth=0,
                                                                figsize=(20,10),
                                                                label='Fox News')
news_sentiments_df[news_sentiments_df['TwitterHandle'] == 'nytimes'].plot(x='TweetsAgo', 
                                                                y='Compound', 
                                                                ax=ax, 
                                                                grid=True,
                                                                marker="+",
                                                                linewidth=0,
                                                                figsize=(20,10),
                                                                label='NY Times')
ax.set_title("Sentiment Analysis of Tweets from News Channels")
plt.ylabel("News Tweet Polarity")
plt.xlabel("Tweets Ago")
plt.legend(loc="best")
plt.show()

# Save image to Image folder
fig.savefig('Images/AllSentiments.jpg')

# %%
# Prepare bar chart of average compound sentiment by Twitter handle
grouped_sentiments = news_sentiments_df.groupby(news_sentiments_df["TwitterHandle"]).mean()["Compound"]
grouped_sentiments.head()
# Out:
# TwitterHandle
# BBC        0.150169
# CBS        0.156082
# CNN       -0.025878
# FoxNews   -0.059860
# nytimes   -0.043024
# Name: Compound, dtype: float64

# %%
legends = ["BBC", "CBS", "CNN", "Fox News", "NY Times"]
grouped_sentiments.plot(kind="barh",
                       x="TwitterHandle", 
                       y='Compound', 
                       grid=True,
                       figsize=(20,10))

# Save image to Image folder
plt.ylabel("Twitter Handle")
plt.xlabel("Tweet Polarity")
plt.savefig('Images/AverageSentiments.jpg')
